# %% [markdown]
# # Set Up

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

# %% [markdown]
# ## Go to kaggle and try to find csv of one ticker or coin

# %%
# save in your file dir

# read in with pandas

# do some messing around with your dataframe to understand the data

# try to plot it

# %% [markdown]
# # Testing Environment
